# %% [markdown]
# # <font color = 'blue'> Car Price Prediction
#
# ### Problem statement
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# - Which variables are significant in predicting the price of a car
# - How well those variables describe the price of a car

# %% [markdown]
# ## Step 1: Reading and Understanding the Data

# %% [markdown]
# ### <font color='blue'>1.1 Import Libraries

# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
import datetime as dt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
#RFE (recursive feature elimination)
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# ### <font color='blue'>1.2 Data Sourcing

# %%
Car_data=pd.read_csv("CarPrice_Assignment.csv",encoding = "ISO-8859-1",low_memory=False)

# %%
Car_data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
print("Dataset have {} rows and {} columns.".format(Car_data.shape[0],Car_data.shape[1]))
# Out:
# Dataset have 205 rows and 26 columns.

# %%
Car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# car_ID              205 non-null int64
# symboling           205 non-null int64
# CarName             205 non-null object
# fueltype            205 non-null object
# aspiration          205 non-null object
# doornumber          205 non-null object
# carbody             205 non-null object
# drivewheel          205 non-null object
# enginelocation      205 non-null object
# wheelbase           205 non-null float64
# carlength           205 non-null float64
# carwidth            205 non-null float64
# carheight           205 non-null float64
# curbweight          205 non-null int64
# enginetype          205 non-null object
# cylindernumber      205 non-null object
# enginesize          205 non-null int64
# fuelsystem          205 non-null object
# boreratio           205 non-null float64
# stroke              205 non-null float64
# compressionratio    205 non-null float64
# ...

# %% [markdown]
# #### <font color='green'> No null values are present in data

# %%
Car_data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# # Step 2 :Data Cleaning and Preparation

# %%
Car_data['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
# Splitting carName into two parts - a) comapny name b) model name 

Car_data['company_name']=Car_data['CarName'].apply(lambda x: x.split()[0].strip() if x else None)
print(Car_data['company_name'].head())

#Car_data['car_model']=Car_data['CarName'].apply(lambda x: ' '.join(x.split(' ')[1:]))
#print(Car_data['car_model'].head())
# Out:
# 0    alfa-romero
# 1    alfa-romero
# 2    alfa-romero
# 3           audi
# 4           audi
# Name: company_name, dtype: object

# %%
Car_data.drop(['CarName'],axis=1,inplace=True)
Car_data.head()
# Out:
#    car_ID  symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0       1          3      gas        std        two  convertible        rwd
# 1       2          3      gas        std        two  convertible        rwd
# 2       3          1      gas        std        two    hatchback        rwd
# 3       4          2      gas        std       four        sedan        fwd
# 4       5          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  ...  fuelsystem  boreratio  stroke  \
# 0          front       88.6      168.8  ...        mpfi       3.47    2.68
# 1          front       88.6      168.8  ...        mpfi       3.47    2.68
# 2          front       94.5      171.2  ...        mpfi       2.68    3.47
# 3          front       99.8      176.6  ...        mpfi       3.19    3.40
# 4          front       99.4      176.6  ...        mpfi       3.19    3.40
#
# ...

# %%
Car_data.company_name.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %% [markdown]
# #### <font color ='green' > There is some Spelling mistake as well as case sesitive names like:
# * <font color ='green' > maxda = mazda
# * <font color ='green' > Nissan = nissan
# * <font color ='green' > porcshce = porsche
# * <font color ='green' > toyouta = toyota
# * <font color ='green' > vokswagen = vw = volkswagen
#
#
# - <font color ='green' > So considering the right most as correct company names and replacing them .

# %%
Car_data.company_name = Car_data.company_name.str.lower()


Car_data.company_name.replace('maxda','mazda',inplace=True)
Car_data.company_name.replace('porcshce','porsche',inplace=True)
Car_data.company_name.replace('toyouta','toyota',inplace=True)
Car_data.company_name.replace('vokswagen','volkswagen',inplace=True)
Car_data.company_name.replace('vw','volkswagen',inplace=True)

Car_data.company_name.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %% [markdown]
# ## Step 2: Visualising the Data
#
# To identify
# - If there is some obvious multicollinearity going on
# - If some predictors directly have a strong association with the outcome variable

# %% [markdown]
# ### <font color='blue'> 2.1 Visualising Numeric Variables

# %%
sns.pairplot(Car_data)
plt.show()

# %% [markdown]
# #### <font color ='green'> Since pairplots for all numeric values together are not clear we can make groups , do plot with price and analyse

# %%
# considering car dimensions first , such as length , widhth , height and weight

def pair_plot(a,b,c,d):
    sns.pairplot(Car_data, x_vars=[a,b,c,d], y_vars='price',size=4, kind='scatter')
    plt.show()

pair_plot('carlength','carwidth','carheight','curbweight')

# %% [markdown]
# #### <font color = 'green'> - Carlength , carwidhth and carweight increases with increase in price , showing a positive correlation.
# #### <font color = 'green'> - Carwidhth doesnot have any proper positive or negative trend with price , rather it is distributed all around.

# %%
# Taking other numeric variables together
sns.set_context("paper", rc={"axes.labelsize":20})
listt=['enginesize','boreratio','stroke','compressionratio','horsepower']
sns.pairplot(Car_data, x_vars=listt, y_vars='price',size=4, aspect=1, kind='scatter')


plt.show()

# %% [markdown]
# #### <font color='green'> - enginesize, boreratio, horsepower  have a  positive correlation/trend with price.
# #### <font color='green'> - stroke and compression ratio doesn't show any significant trend with price.

# %%
# Taking other numeric variables together

listt=['peakrpm','citympg','highwaympg','wheelbase','symboling']
sns.pairplot(Car_data, x_vars=listt, y_vars='price',size=4, aspect=1, kind='scatter',height=20)

plt.show()

# %% [markdown]
# #### <font color='green'> - citympg, highwaympg - seem to have a significant negative correlation with price.
# #### <font color='green'> - Wheelbase is having a positive correlation with price

# %% [markdown]
# ### <font color='blue'> 2.2 Visualising Categorical Variables

# %%
plt.figure(figsize=(20, 20))
plt.subplot(4,3,1)
sns.boxplot(x = 'company_name', y = 'price', data = Car_data)
plt.subplot(4,3,2)
sns.boxplot(x = 'fueltype', y = 'price', data = Car_data)
plt.subplot(4,3,3)
sns.boxplot(x = 'aspiration', y = 'price', data = Car_data)
plt.subplot(4,3,4)
sns.boxplot(x = 'doornumber', y = 'price', data = Car_data)
plt.subplot(4,3,5)
sns.boxplot(x = 'carbody', y = 'price', data = Car_data)
plt.subplot(4,3,6)
sns.boxplot(x = 'drivewheel', y = 'price', data = Car_data)
plt.subplot(4,3,7)
sns.boxplot(x = 'enginelocation', y = 'price', data = Car_data)
plt.subplot(4,3,8)
sns.boxplot(x = 'enginetype', y = 'price', data = Car_data)
plt.subplot(4,3,9)
sns.boxplot(x = 'cylindernumber', y = 'price', data = Car_data)
plt.subplot(4,3,10)
sns.boxplot(x = 'fuelsystem', y = 'price', data = Car_data)
plt.show()

# %% [markdown]
# #### <font color='green'> There is no significant variation in categories of door number.
# #### <font color='green'>Turbo category of Aspiration is has higher price range than std
# #### <font color='green'>Cylindernumber 'eight' is having highest price range
# #### <font color='green'>mpfi and idi having the highest price range. There is very less data for  categories like mfi,spfi to make any inference
# #### <font color='green'>rwd drivewheel are having high price range

# %% [markdown]
# After visualization , variables to be considered which is affecting price:
# - Engine Type
# - Fuel type
# fuel system
# - Car Body
# doornumber
# engine location
# - Aspiration
# - Cylinder Number
# - Drivewheel
# - Curbweight
# - Car Length
# - Car width
# - Engine Size
# - Boreratio
# - Horse Power
# - Wheel base
# -citympg
# -highwaympg

# %% [markdown]
# Car_data.columns
# 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth',  'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio',
#        'horsepower', 'citympg', 'highwaympg', 'price'

# %% [markdown]
# ### <font color ='blue' > 2.3 Correlation Matrix for numeric variables

# %%
#To find correlation among varibales
corr = Car_data.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap='RdYlGn')

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});
ax.tick_params(labelsize=20)

# %%
f, ax = plt.subplots(figsize=(20, 9))
sns.heatmap(corr.apply(lambda x : np.round(x,2)), 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,annot=True,cmap='RdYlGn', annot_kws={"size": 15})
ax.tick_params(labelsize=20)
plt.show()

# %% [markdown]
# #### <font color = 'green'> -  Wheel base is having high positive correlation with carlength (0.87),carwidth (0.8) ,curbweight(0.78)
# #### <font color = 'green'> - Carlength and carweight is having high positive correlation among each other
# #### <font color = 'green'> - curbweight is having high positive correlation with enginesize(0.85) and price(0.84).  curbweight is having high negative correlation with highwaympg(-0.8)and citympg(-0.76)
# #### <font color = 'green'> - enginesize is having high correlation with horsepower
# #### <font color = 'green'> - Highwaympg is having very high positive correlation with citympg(0.97)
# #### <font color = 'green'> - Price is having high positive correlation with curbweight,enginesize and horsepower and negative correlation with highwaypg

# %%
###try derived variable car range afterwatrds

# %%
bins = [0,10000,20000,60000]
cars_price_bin=['Low','Medium','High']
Car_data['car_price_range'] = pd.cut(Car_data['price'],bins,right=False,labels=cars_price_bin)
Car_data['car_price_range'].unique()
# Out:
# [Medium, High, Low]
# Categories (3, object): [Low < Medium < High]

# %%
  
#Car_data['symboling']=Car_data['symboling'].astype(str)

# %%
# Defining the map function
#varlist=['symboling']
#def binary_map(x):
#    return x.map({-1: "Low_risk",-2: "Low_risk",0: "Medium_risk", 1:"Medium_risk",3: "High_risk", 2:"High_risk"})

# Applying the function to the car data list
#Car_data['symboling_risk'] = Car_data[varlist].apply(binary_map)
#Car_data['symboling_risk'] .unique()

# %%
df=Car_data[['price',  'aspiration','carbody', 'drivewheel','wheelbase',
                  'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'boreratio','horsepower', 
                    'carlength','carwidth', 'car_price_range']]

# %% [markdown]
# # step 3 Data Preparation
# - Converting categorical variables to dummy variables

# %% [markdown]
# #### <font color='green'> Converting string to numerical value,  we need to do binary conversion of categorical variables having 2 values ,by converting them to 1s and 0s, where 1 is value is true there and 0 where value is false

# %%
# Subsetting data as per visualized important parameters
#df=Car_data[['fueltype', 'aspiration', 'doornumber','carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength','carwidth', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio','horsepower', 'citympg', 'highwaympg', 'price']]
#df=Car_data.copy()
df.head()
# Out:
#      price aspiration      carbody drivewheel  wheelbase  curbweight  \
# 0  13495.0        std  convertible        rwd       88.6        2548
# 1  16500.0        std  convertible        rwd       88.6        2548
# 2  16500.0        std    hatchback        rwd       94.5        2823
# 3  13950.0        std        sedan        fwd       99.8        2337
# 4  17450.0        std        sedan        4wd       99.4        2824
#
#   enginetype cylindernumber  enginesize  boreratio  horsepower  carlength  \
# 0       dohc           four         130       3.47         111      168.8
# 1       dohc           four         130       3.47         111      168.8
# 2       ohcv            six         152       2.68         154      171.2
# 3        ohc           four         109       3.19         102      176.6
# 4        ohc           five         136       3.19         115      176.6
#
#    carwidth car_price_range
# 0      64.1          Medium
# 1      64.1          Medium
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 14 columns):
# price              205 non-null float64
# aspiration         205 non-null object
# carbody            205 non-null object
# drivewheel         205 non-null object
# wheelbase          205 non-null float64
# curbweight         205 non-null int64
# enginetype         205 non-null object
# cylindernumber     205 non-null object
# enginesize         205 non-null int64
# boreratio          205 non-null float64
# horsepower         205 non-null int64
# carlength          205 non-null float64
# carwidth           205 non-null float64
# car_price_range    205 non-null category
# dtypes: category(1), float64(5), int64(3), object(5)
# memory usage: 21.2+ KB

# %%
def create_dummy1(x,Car_data1):
    status = pd.get_dummies(Car_data1[x], drop_first = True,prefix=x)
    Car_data1 = pd.concat([Car_data1, status], axis = 1)
    Car_data1.drop([x], axis = 1, inplace = True)
    return Car_data1



#df = create_dummy1('fueltype',df)
#df = create_dummy1('fuelsystem',df)
df = create_dummy1('aspiration',df)
df = create_dummy1('carbody',df)
df = create_dummy1('drivewheel',df)
df = create_dummy1('enginetype',df)
df = create_dummy1('cylindernumber',df)
#df = create_dummy1('doornumber',df)
#df = create_dummy1('enginelocation',df)
df = create_dummy1('car_price_range',df)
#df = create_dummy1('symboling_risk',df)
#df = create_dummy1('company_name',df)
df.head()
# Out:
#      price  wheelbase  curbweight  enginesize  boreratio  horsepower  \
# 0  13495.0       88.6        2548         130       3.47         111
# 1  16500.0       88.6        2548         130       3.47         111
# 2  16500.0       94.5        2823         152       2.68         154
# 3  13950.0       99.8        2337         109       3.19         102
# 4  17450.0       99.4        2824         136       3.19         115
#
#    carlength  carwidth  aspiration_turbo  carbody_hardtop  ...  \
# 0      168.8      64.1                 0                0  ...
# 1      168.8      64.1                 0                0  ...
# 2      171.2      65.5                 0                0  ...
# 3      176.6      66.2                 0                0  ...
# 4      176.6      66.4                 0                0  ...
#
#    enginetype_ohcv  enginetype_rotor  cylindernumber_five  \
# 0                0                 0                    0
# ...

# %% [markdown]
# #Categories having minimum count and can be removed:
#
# - Cylinder number three and column
# -engineType dohcv
# - fuel system mfi,spfi

# %%
df.columns
# Out:
# Index(['price', 'wheelbase', 'curbweight', 'enginesize', 'boreratio',
#        'horsepower', 'carlength', 'carwidth', 'aspiration_turbo',
#        'carbody_hardtop', 'carbody_hatchback', 'carbody_sedan',
#        'carbody_wagon', 'drivewheel_fwd', 'drivewheel_rwd', 'enginetype_dohcv',
#        'enginetype_l', 'enginetype_ohc', 'enginetype_ohcf', 'enginetype_ohcv',
#        'enginetype_rotor', 'cylindernumber_five', 'cylindernumber_four',
#        'cylindernumber_six', 'cylindernumber_three', 'cylindernumber_twelve',
#        'cylindernumber_two', 'car_price_range_Medium', 'car_price_range_High'],
#       dtype='object')

# %%
df=df[['price', 'wheelbase', 'curbweight', 'enginesize', 'boreratio',
       'horsepower', 'carlength', 'carwidth', 'aspiration_turbo',
       'carbody_hardtop', 'carbody_hatchback', 'carbody_sedan',
       'carbody_wagon', 'drivewheel_fwd', 'drivewheel_rwd', 
       'enginetype_l', 'enginetype_ohc', 'enginetype_ohcf', 'enginetype_ohcv',
       'enginetype_rotor', 'cylindernumber_five', 'cylindernumber_four',
       'cylindernumber_six', 
       'cylindernumber_two', 'car_price_range_Medium', 'car_price_range_High']]

# %%
# Step 4: Splitting the Data into Training and Testing Sets

# %%
# We specify this so that the train and test data set always have the same rows, respectively
np.random.seed(0)
df_train, df_test = train_test_split(df, train_size = 0.75, test_size = 0.25, random_state = 42)

# %% [markdown]
# ### Rescaling the feature using Min-Max Scaler

# %%
scaler = MinMaxScaler()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# price                     205 non-null float64
# wheelbase                 205 non-null float64
# curbweight                205 non-null int64
# enginesize                205 non-null int64
# boreratio                 205 non-null float64
# horsepower                205 non-null int64
# carlength                 205 non-null float64
# carwidth                  205 non-null float64
# aspiration_turbo          205 non-null uint8
# carbody_hardtop           205 non-null uint8
# carbody_hatchback         205 non-null uint8
# carbody_sedan             205 non-null uint8
# carbody_wagon             205 non-null uint8
# drivewheel_fwd            205 non-null uint8
# drivewheel_rwd            205 non-null uint8
# enginetype_l              205 non-null uint8
# enginetype_ohc            205 non-null uint8
# enginetype_ohcf           205 non-null uint8
# ...

# %%
# Apply scaler() to all the columns except the 'yes-no' and 'dummy' variables

num_vars = [ 'wheelbase', 'carlength', 'carwidth', 'curbweight', 'enginesize', 'boreratio','horsepower']

df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train.head()
# Out:
#        price  wheelbase  curbweight  enginesize  boreratio  horsepower  \
# 90    7099.0   0.272414    0.088117    0.128906   0.321429    0.012712
# 173   8948.0   0.544828    0.225634    0.203125   0.550000    0.169492
# 93    7349.0   0.272414    0.091233    0.105469   0.435714    0.072034
# 5    15250.0   0.455172    0.306186    0.257812   0.464286    0.245763
# 167   8449.0   0.406897    0.320872    0.296875   0.771429    0.271186
#
#      carlength  carwidth  aspiration_turbo  carbody_hardtop  ...  \
# 90    0.356897  0.190476                 0                0  ...
# 173   0.534483  0.447619                 0                0  ...
# 93    0.441379  0.190476                 0                0  ...
# 5     0.563793  0.428571                 0                0  ...
# 167   0.544828  0.361905                 0                1  ...
#
#      enginetype_ohc  enginetype_ohcf  enginetype_ohcv  enginetype_rotor  \
# ...

# %%
df_train.describe()
# Out:
#               price   wheelbase  curbweight  enginesize   boreratio  \
# count    153.000000  153.000000  153.000000  153.000000  153.000000
# mean   13367.352941    0.417760    0.330532    0.222171    0.558217
# std     7904.190990    0.206955    0.228887    0.160932    0.193697
# min     5118.000000    0.000000    0.000000    0.000000    0.000000
# 25%     7895.000000    0.272414    0.165109    0.109375    0.435714
# 50%    10698.000000    0.355172    0.269693    0.195312    0.550000
# 75%    16515.000000    0.503448    0.496662    0.277344    0.714286
# max    45400.000000    1.000000    1.000000    1.000000    1.000000
#
#        horsepower   carlength    carwidth  aspiration_turbo  carbody_hardtop  \
# count  153.000000  153.000000  153.000000        153.000000       153.000000
# mean     0.227623    0.513230    0.395518          0.176471         0.032680
# std      0.172040    0.209085    0.203432          0.382472         0.178381
# ...

# %%
# Let's check the correlation coefficients to see which variables are highly correlated

#plt.figure(figsize = (30, 25))
#sns.heatmap(df_train.corr(), annot = True, cmap="RdYlGn")
#plt.show()

# %%
#Dividing data into X and y variables
y_train = df_train.pop('price')
X_train = df_train

# %% [markdown]
# # Step 5 : Building a linear model

# %% [markdown]
# ### Selecting features first using Recursive feature elimination (RFE)

# %%
X_train.columns
# Out:
# Index(['wheelbase', 'curbweight', 'enginesize', 'boreratio', 'horsepower',
#        'carlength', 'carwidth', 'aspiration_turbo', 'carbody_hardtop',
#        'carbody_hatchback', 'carbody_sedan', 'carbody_wagon', 'drivewheel_fwd',
#        'drivewheel_rwd', 'enginetype_l', 'enginetype_ohc', 'enginetype_ohcf',
#        'enginetype_ohcv', 'enginetype_rotor', 'cylindernumber_five',
#        'cylindernumber_four', 'cylindernumber_six', 'cylindernumber_two',
#        'car_price_range_Medium', 'car_price_range_High'],
#       dtype='object')

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
rfe = RFE(lm, 10)
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('wheelbase', False, 2),
#  ('curbweight', True, 1),
#  ('enginesize', True, 1),
#  ('boreratio', False, 3),
#  ('horsepower', True, 1),
#  ('carlength', False, 4),
#  ('carwidth', True, 1),
#  ('aspiration_turbo', False, 16),
#  ('carbody_hardtop', False, 8),
#  ('carbody_hatchback', True, 1),
#  ('carbody_sedan', True, 1),
#  ('carbody_wagon', True, 1),
#  ('drivewheel_fwd', False, 13),
#  ('drivewheel_rwd', False, 10),
#  ('enginetype_l', False, 15),
#  ('enginetype_ohc', False, 12),
#  ('enginetype_ohcf', False, 5),
#  ('enginetype_ohcv', False, 11),
#  ('enginetype_rotor', True, 1),
#  ('cylindernumber_five', False, 9),
#  ('cylindernumber_four', False, 14),
#  ('cylindernumber_six', False, 7),
#  ('cylindernumber_two', False, 6),
#  ('car_price_range_Medium', True, 1),
#  ('car_price_range_High', True, 1)]

# %%
X_train.columns[rfe.support_]
# Out:
# Index(['curbweight', 'enginesize', 'horsepower', 'carwidth',
#        'carbody_hatchback', 'carbody_sedan', 'carbody_wagon',
#        'enginetype_rotor', 'car_price_range_Medium', 'car_price_range_High'],
#       dtype='object')

# %% [markdown]
# Considering parameter with rfe ranking as 1 first and build model :
#
#     'wheelbase','curbweight','enginesize','horsepower','highwaympg','hardtop','hatchback','sedan','wagon','rear'
#
#
#
#     'boreratio','stroke','three','twelve','two','bmw' ,'rear'
#
# 'horsepower', 'fueleconomy',  ,
#        'sedan', 'wagon', 'dohcv',  'Highend'

# %%
X_train_rfe = X_train[X_train.columns[rfe.support_]]
X_train_rfe.head()
# Out:
#      curbweight  enginesize  horsepower  carwidth  carbody_hatchback  \
# 90     0.088117    0.128906    0.012712  0.190476                  0
# 173    0.225634    0.203125    0.169492  0.447619                  0
# 93     0.091233    0.105469    0.072034  0.190476                  0
# 5      0.306186    0.257812    0.245763  0.428571                  0
# 167    0.320872    0.296875    0.271186  0.361905                  0
#
#      carbody_sedan  carbody_wagon  enginetype_rotor  car_price_range_Medium  \
# 90               1              0                 0                       0
# 173              1              0                 0                       0
# 93               0              1                 0                       0
# 5                1              0                 0                       1
# 167              0              0                 0                       0
#
#      car_price_range_High
# 90                      0
# 173                     0
# ...

# %%
# Functions for model building and calculating VIF

def model_creation(X,y):
    X = sm.add_constant(X) #Adding the constant
    lm = sm.OLS(y,X).fit() # fitting the model
    print(lm.summary()) # model summary
    return X
    
def VIF_calculate(X):
    vif = pd.DataFrame()
    vif['Features'] = X.columns
    vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif['VIF'] = round(vif['VIF'], 2)
    vif = vif.sort_values(by = "VIF", ascending = False)
    return(vif)

# %% [markdown]
# ### MODEL 1

# %%
X_train_new = model_creation(X_train_rfe,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.936
# Method:                 Least Squares   F-statistic:                     221.6
# Date:                Mon, 17 Feb 2020   Prob (F-statistic):           2.21e-81
# Time:                        23:55:29   Log-Likelihood:                -1374.9
# No. Observations:                 153   AIC:                             2772.
# Df Residuals:                     142   BIC:                             2805.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   7328.1428    787.013      9.311      0.000    5772.367    8883.918
# ...

# %%
VIF_calculate(X_train_rfe)
# Out:
#                  Features    VIF
# 0              curbweight  28.21
# 1              enginesize  19.56
# 3                carwidth  17.88
# 2              horsepower   9.68
# 8  car_price_range_Medium   4.35
# 9    car_price_range_High   4.15
# 5           carbody_sedan   3.06
# 4       carbody_hatchback   2.50
# 6           carbody_wagon   1.94
# 7        enginetype_rotor   1.28

# %% [markdown]
# #### <font color='green'> car length is having high VIF and High p value to removing it first

# %% [markdown]
# ### MODEL 2

# %%
X_train_1= X_train_rfe.drop(["curbweight"], axis = 1)

# %%
X_train_new = model_creation(X_train_1,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.935
# Method:                 Least Squares   F-statistic:                     242.3
# Date:                Mon, 17 Feb 2020   Prob (F-statistic):           6.28e-82
# Time:                        23:55:29   Log-Likelihood:                -1376.5
# No. Observations:                 153   AIC:                             2773.
# Df Residuals:                     143   BIC:                             2803.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   6992.4882    768.916      9.094      0.000    5472.577    8512.399
# ...

# %%
VIF_calculate(X_train_1)
# Out:
#                  Features    VIF
# 0              enginesize  14.04
# 2                carwidth  13.80
# 1              horsepower   9.66
# 8    car_price_range_High   3.97
# 7  car_price_range_Medium   3.55
# 4           carbody_sedan   3.05
# 3       carbody_hatchback   2.39
# 5           carbody_wagon   1.76
# 6        enginetype_rotor   1.26

# %%
#### <font color='green'> five is having highest p value (most insignificant) so removing it first

# %% [markdown]
# ### MODEL 3

# %%
X_train_1= X_train_1.drop(["enginesize"], axis = 1)

# %%
X_train_new = model_creation(X_train_1,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.928
# Method:                 Least Squares   F-statistic:                     245.0
# Date:                Mon, 17 Feb 2020   Prob (F-statistic):           7.68e-80
# Time:                        23:55:30   Log-Likelihood:                -1384.6
# No. Observations:                 153   AIC:                             2787.
# Df Residuals:                     144   BIC:                             2815.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   7857.3162    775.700     10.129      0.000    6324.088    9390.545
# ...

# %%
VIF_calculate(X_train_1)
# Out:
#                  Features    VIF
# 1                carwidth  11.68
# 0              horsepower   6.14
# 7    car_price_range_High   3.63
# 6  car_price_range_Medium   3.55
# 3           carbody_sedan   3.05
# 2       carbody_hatchback   2.39
# 4           carbody_wagon   1.76
# 5        enginetype_rotor   1.12

# %% [markdown]
# #### <font size='green'> car weigth

# %% [markdown]
# ### MODEL 4

# %%
X_train_1= X_train_1.drop(["cylindernumber_two"], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-2d3b2df1279e> in <module>
# ----> 1 X_train_1= X_train_1.drop(["cylindernumber_two"], axis = 1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
X_train_new = model_creation(X_train_1,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.928
# Method:                 Least Squares   F-statistic:                     245.0
# Date:                Mon, 17 Feb 2020   Prob (F-statistic):           7.68e-80
# Time:                        23:55:41   Log-Likelihood:                -1384.6
# No. Observations:                 153   AIC:                             2787.
# Df Residuals:                     144   BIC:                             2815.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   7857.3162    775.700     10.129      0.000    6324.088    9390.545
# ...

# %%
VIF_calculate(X_train_1)
# Out:
#                  Features    VIF
# 1                carwidth  11.68
# 0              horsepower   6.14
# 7    car_price_range_High   3.63
# 6  car_price_range_Medium   3.55
# 3           carbody_sedan   3.05
# 2       carbody_hatchback   2.39
# 4           carbody_wagon   1.76
# 5        enginetype_rotor   1.12

# %% [markdown]
# #### <font color='green'> sedan remove

# %% [markdown]
# ### MODEL 5

# %%
X_train_1= X_train_1.drop(["carwidth"], axis = 1)

# %%
X_train_new = model_creation(X_train_1,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.909
# Method:                 Least Squares   F-statistic:                     216.8
# Date:                Mon, 17 Feb 2020   Prob (F-statistic):           1.76e-73
# Time:                        23:55:43   Log-Likelihood:                -1403.2
# No. Observations:                 153   AIC:                             2822.
# Df Residuals:                     145   BIC:                             2847.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   8241.7066    869.764      9.476      0.000    6522.653    9960.761
# ...

# %%
VIF_calculate(X_train_1)
# Out:
#                  Features   VIF
# 0              horsepower  5.58
# 5  car_price_range_Medium  2.79
# 6    car_price_range_High  2.77
# 1       carbody_hatchback  1.65
# 2           carbody_sedan  1.65
# 3           carbody_wagon  1.26
# 4        enginetype_rotor  1.11

# %% [markdown]
# #removing highwaympg

# %% [markdown]
# ### MODEL 6

# %%
X_train_1= X_train_1.drop(["carbody_wagon"], axis = 1)

# %%
X_train_new = model_creation(X_train_1,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                     249.8
# Date:                Mon, 17 Feb 2020   Prob (F-statistic):           3.87e-74
# Time:                        23:55:43   Log-Likelihood:                -1404.5
# No. Observations:                 153   AIC:                             2823.
# Df Residuals:                     146   BIC:                             2844.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   7181.9215    575.221     12.485      0.000    6045.085    8318.758
# ...

# %%
VIF_calculate(X_train_1)
# Out:
#                  Features   VIF
# 0              horsepower  5.27
# 5    car_price_range_High  2.73
# 4  car_price_range_Medium  2.71
# 1       carbody_hatchback  1.56
# 2           carbody_sedan  1.54
# 3        enginetype_rotor  1.11

# %% [markdown]
# ### four wagon

# %% [markdown]
# ### MODEL 7

# %%
X_train_1= X_train_1.drop(["carbody_sedan"], axis = 1)

# %%
X_train_new = model_creation(X_train_1,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.909
# Model:                            OLS   Adj. R-squared:                  0.906
# Method:                 Least Squares   F-statistic:                     293.6
# Date:                Mon, 17 Feb 2020   Prob (F-statistic):           1.33e-74
# Time:                        23:55:44   Log-Likelihood:                -1406.5
# No. Observations:                 153   AIC:                             2825.
# Df Residuals:                     147   BIC:                             2843.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   6337.0354    375.174     16.891      0.000    5595.605    7078.466
# ...

# %%
VIF_calculate(X_train_1)
# Out:
#                  Features   VIF
# 0              horsepower  4.92
# 4    car_price_range_High  2.73
# 3  car_price_range_Medium  2.64
# 1       carbody_hatchback  1.44
# 2        enginetype_rotor  1.10

# %% [markdown]
# #dohcv     remove high p  value

# %%
xcol=list(X_train_rfe.columns)

xcol.append('curbweight')
X_train_1 = X_train_1[xcol[1:]]

X_train_new = model_creation(X_train_1,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-caee9283b278> in <module>
#       2
#       3 xcol.append('curbweight')
# ----> 4 X_train_1 = X_train_1[xcol[1:]]
#       5
#       6 X_train_new = model_creation(X_train_1,y_train)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# ...

# %%
VIF_calculate(X_train_1)
# Out:
#                  Features   VIF
# 0              horsepower  4.92
# 4    car_price_range_High  2.73
# 3  car_price_range_Medium  2.64
# 1       carbody_hatchback  1.44
# 2        enginetype_rotor  1.10

# %%
# Residual Analysis on test data

# %%
lm = sm.OLS(y_train,X_train_new).fit()
y_train_price = lm.predict(X_train_new)

# %%
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_price), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading 
plt.xlabel('Errors', fontsize = 18)
# Out:
# Text(0.5, 0, 'Errors')

# %%
# prediction and evaluation

# %%
 
num_vars = [ 'wheelbase', 'carlength', 'carwidth', 'curbweight', 'enginesize', 'boreratio','horsepower']
df_test[num_vars] = scaler.transform(df_test[num_vars])

# %%
#Dividing into X and y
y_test = df_test.pop('price')
X_test = df_test

# %%
# Adding constant variable to test dataframe
X_test_1 = sm.add_constant(X_test)

# %%
# Creating X_test_m4 dataframe by dropping variables from X_test_m4

X_test_1 =  X_test_1[X_train_new.columns]

# %%
y_pred_1 = lm.predict(X_test_1)

# %%
fig = plt.figure()
plt.scatter(y_test, y_pred_1)
fig.suptitle('y_test vs y_pred', fontsize = 20)              # Plot heading 
plt.xlabel('y_test', fontsize = 18)                          # X-label
plt.ylabel('y_pred', fontsize = 16)
# Out:
# Text(0, 0.5, 'y_pred')

# %%
from sklearn.metrics import r2_score 
r2_score(y_true=y_train,y_pred=y_train_price)
# Out:
# 0.9089751596628644

# %%
from sklearn.metrics import r2_score 
r2_score(y_test, y_pred_1)
# Out:
# 0.885100025814529

# %%
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.909
# Model:                            OLS   Adj. R-squared:                  0.906
# Method:                 Least Squares   F-statistic:                     293.6
# Date:                Mon, 17 Feb 2020   Prob (F-statistic):           1.33e-74
# Time:                        23:55:49   Log-Likelihood:                -1406.5
# No. Observations:                 153   AIC:                             2825.
# Df Residuals:                     147   BIC:                             2843.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   6337.0354    375.174     16.891      0.000    5595.605    7078.466
# ...
